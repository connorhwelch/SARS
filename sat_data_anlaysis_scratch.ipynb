# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import satpy
import metpy
from pathlib import Path

from pyart.default_config import corrected_reflectivity

from SARS.satellite_data_processor import pixel_selector

# %%
data_dir = Path('~/Downloads/sars_p1_data/processed_output').expanduser()
corrected_data_paths = sorted(data_dir.glob('*corrected*'))
uncorrected_data_paths = sorted(data_dir.glob('*unc*'))

# %%
pixel_data = {}

for i in range(len(corrected_data_paths)):
    corrected_data_path = corrected_data_paths[i]
    name = corrected_data_paths[i].stem.split('_')[0]
    for pixel_class, lon_lat in sat_pixel_class_points[name].items():
        pixel_data[name][pixel_class] = pixel_selector(ds, lon_lat, radius=1)
# Out:
# noaa20
# noaa20
# noaa20
# noaa20
# noaa20
# noaa20
# sentinel2b
# sentinel2b
# sentinel2b
# sentinel2b
# sentinel2b
# sentinel2b
# sentinel2b
# sentinel2b
# sentinel2b
# sentinel2b
# sentinel2b
# sentinel2b
# sentinel2b
# sentinel2b
# sentinel2b
# sentinel2b
# sentinel2b
# sentinel2b
# terra
# terra
# terra
# terra
# terra
# terra

# %%
pixel_data = {
    'terra':{},
    'noaa20':{},
    'sentinel2b':{},
}
